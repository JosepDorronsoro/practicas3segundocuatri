# %% [markdown]
# # Conditional generation (CFG) + Imputation — color digits SVHN
#
# This notebook has two parts:
#
# **Part 1 — Conditional generation with CFG**
# Loads the three checkpoints from `color_digits_cond_checkpoints/` (VP-Linear, VP-Cosine, VP-Exponential) and generates class-conditional samples using `CondUNetScoreModel` + `CFGWrapper` from `diffusion_lib`.
#
# **Part 2 — Imputation**
# Loads the unconditional VP-Cosine checkpoint from `color_digits_checkpoints/` and reconstructs masked regions of real SVHN images using `ImputationSampler`.

# %%
import sys
from pathlib import Path

import numpy as np
import torch
import scipy.io
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# Resolve project root whether the notebook is run from notebooks_extra/ or project root
PROJECT_DIR = Path.cwd()
if not (PROJECT_DIR / 'diffusion_lib').exists():
    PROJECT_DIR = PROJECT_DIR.parent          # notebooks_extra/ → raíz del proyecto
if not (PROJECT_DIR / 'diffusion_lib').exists():
    raise RuntimeError(f'Cannot locate diffusion_lib from {Path.cwd()}')
sys.path.insert(0, str(PROJECT_DIR))

from diffusion_lib import (
    VPProcess,
    LinearSchedule, CosineSchedule, ExponentialSchedule,
    CondUNetScoreModel,
    CFGWrapper,
    ImputationSampler,
)

device = 'mps'
print('Project dir:', PROJECT_DIR)
print('Device:', device)
# Out:
# Project dir: /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models
# Device: mps

# %% [markdown]
# ---
# ## Part 1 — Conditional generation with Classifier-Free Guidance
#
# The three conditional checkpoints were trained with the same U-Net architecture as `CondUNetScoreModel`.
# The guided score is:
# $$s_\text{CFG}(x,t,y) = s_\theta(x,t,\emptyset) + w\,\bigl[s_\theta(x,t,y) - s_\theta(x,t,\emptyset)\bigr]$$

# %%
COND_CKPT_DIR = PROJECT_DIR / 'color_digits_cond_checkpoints'

COND_PROCESSES = {
    'VP-Linear':      VPProcess(schedule=LinearSchedule()),
    'VP-Cosine':      VPProcess(schedule=CosineSchedule()),
    'VP-Exponential': VPProcess(schedule=ExponentialSchedule()),
}
T_FOR = {'VP-Linear': 1.0, 'VP-Cosine': 0.999, 'VP-Exponential': 1.0}

cond_models = {}
for name, process in COND_PROCESSES.items():
    ckpt = COND_CKPT_DIR / f'color_digits_{name}.pth'
    model = CondUNetScoreModel(marginal_prob_std=process.sigma_t, n_classes=10).to(device)
    model.load_state_dict(torch.load(ckpt, map_location=device, weights_only=True))
    model.eval()
    cond_models[name] = (process, model)
    print(f'Loaded {ckpt.name}')
# Out:
# Loaded color_digits_VP-Linear.pth
# Loaded color_digits_VP-Cosine.pth
# Loaded color_digits_VP-Exponential.pth

# %%
@torch.no_grad()
def cfg_sample(process, wrapper, n_images, T=1.0, n_steps=500, eps=1e-3):
    """Probability flow ODE (sin término estocástico) — más estable que EM."""
    img_shape = (3, 32, 32)
    x = process.prior_sample((n_images, *img_shape), device) + 0.451
    dt = (eps - T) / n_steps
    t_vals = torch.linspace(T, eps, n_steps + 1, device=device)
    view = [n_images, 1, 1, 1]
    wrapper.eval()
    for i in range(n_steps):
        t = t_vals[i].expand(n_images)
        score = wrapper(x, t)
        # ODE drift: f(x,t) - 0.5 * g²(t) * score
        g2 = process.diffusion_coefficient(t).view(*view) ** 2
        drift = process.drift_coefficient(x, t) - 0.5 * g2 * score
        x = x - drift * dt   # sin término de ruido
    return x

# %% [markdown]
# ### 1.1 Class grid — one row per digit, columns are independent samples
#
# For each process we generate **N_PER_CLASS** samples per digit with guidance scale **W**.

# %%
N_PER_CLASS = 5
W           = 3.0
PROC_SHOW   = 'VP-Linear'    # change to 'VP-Linear' or 'VP-Exponential'

process, model = cond_models[PROC_SHOW]
T = T_FOR[PROC_SHOW]

rows = []
for y in range(10):
    wrapper = CFGWrapper(model, class_label=y, cfg_scale=W)
    sams = cfg_sample(process, wrapper, N_PER_CLASS, T=T).cpu().clamp(0, 1)
    rows.append(sams)
    print(f'  class {y} done')

grid_tensor = torch.cat(rows, dim=0)   # [100, 3, 32, 32]
grid = make_grid(grid_tensor, nrow=N_PER_CLASS)

fig, ax = plt.subplots(figsize=(N_PER_CLASS * 1.2 + 1, 13))
ax.imshow(grid.permute(1, 2, 0).numpy())
ax.set_yticks(np.arange(10) * 33 + 16)
ax.set_yticklabels(list(range(10)), fontsize=12)
ax.set_xticks([])
ax.set_title(f'CFG class grid — {PROC_SHOW}  (w={W})', fontsize=13)
plt.tight_layout()
out_dir = PROJECT_DIR / 'figuras'; out_dir.mkdir(exist_ok=True)
fig.savefig(out_dir / f'cfg_grid_{PROC_SHOW}.pdf', bbox_inches='tight', dpi=150)
plt.show()
# Out:
#   class 0 done
#   class 1 done
#   class 2 done
#   class 3 done
#   class 4 done
#   class 5 done
#   class 6 done
#   class 7 done
#   class 8 done
#   class 9 done

# %%
# Busca en notebooks_extra/ o en la raíz
import subprocess
result = subprocess.run(['find', str(PROJECT_DIR), '-name', '*.py', '-o', '-name', '*.ipynb'], 
                      capture_output=True, text=True)
print(result.stdout)
# Out:
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/cat_AI_v2/cat64_diffusion.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/cat_AI_v2/score_model.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/cat_AI_v2/train_cats.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/notebooks_extra/04_conditional_and_imputation.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/notebooks_extra/01_cfg_class_grid_color_digits.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/notebooks_extra/03_imputation_color_digits.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/notebooks_extra/02_cfg_w_sweep_and_schedules.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/cat_AI/cifar10_cats_diffusion.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/cat_AI/score_model.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/digits_true_color_AI/demo_diffusion_models_generative_AI.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/digits_true_color_AI/score_model.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/train_all_color_digits.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/metrics/fid_is.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/metrics/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/metrics/bpd.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/processes/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/processes/vp.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/processes/ve.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/processes/base.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/schedules/cosine.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/schedules/linear.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/schedules/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/schedules/exponential.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/schedules/base.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/model.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/samplers/predictor_corrector.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/samplers/probability_flow_ode.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/samplers/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/samplers/imputation.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/samplers/euler_maruyama.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/samplers/base.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/score_models/cfg_wrapper.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/score_models/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/score_models/unconditional.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/score_models/conditional.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_lib/score_models/base.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/tests/test_score_models.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/score_model_digits_color.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/generacion_condicionada/cfg_diffusion_models_SVHN.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/generacion_condicionada/score_model.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/bin/activate_this.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/appnope/_nope.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/appnope/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/appnope/_dummy.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/tags.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/_musllinux.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/metadata.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/version.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/licenses/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/licenses/_spdx.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/pylock.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/_parser.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/utils.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/requirements.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/_structures.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/markers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/_manylinux.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/_tokenizer.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/specifiers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/packaging/_elffile.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/cycler/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/gexf.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/gml.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/tree.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/cytoscape.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/tests/test_adjacency.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/tests/test_tree.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/tests/test_node_link.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/tests/test_cytoscape.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/node_link.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/json_graph/adjacency.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/sparse6.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/p2g.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_graph6.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_gexf.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_sparse6.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_p2g.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_pajek.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_gml.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_edgelist.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_adjlist.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_text.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_leda.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/tests/test_graphml.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/multiline_adjlist.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/leda.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/graph6.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/text.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/adjlist.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/pajek.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/graphml.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/readwrite/edgelist.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/nx_latex.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/layout.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/test_agraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/test_latex.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/test_pydot.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/test_image_comparison_pylab_mpl.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/test_pylab.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/tests/test_layout.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/nx_pydot.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/nx_agraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/conftest.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/exception.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/algebraicconnectivity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/bethehessianmatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/laplacianmatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_attrmatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_algebraic_connectivity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_bethehessian.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_modularity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_laplacian.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_spectrum.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/tests/test_graphmatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/modularitymatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/spectrum.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/graphmatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/linalg/attrmatrix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/relabel.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/coreviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/graph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_multidigraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_graphviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_digraph_historical.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/historical_tests.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_multigraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/dispatch_interface.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_coreviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_function.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_special.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_graph_historical.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_filters.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_graph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_subgraphviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_digraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/tests/test_reportviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/multigraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/reportviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/multidigraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/digraph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/filters.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/function.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/classes/graphviews.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/convert.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/recognition.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/coding.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_recognition.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_operations.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_branchings.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_distance_measures.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_decomposition.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_coding.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/tests/test_mst.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/operations.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/branchings.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/mst.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/decomposition.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/tree/distance_measures.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/richclub.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/wiener.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/boundary.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/vf2userfunc.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tree_isomorphism.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/ismags.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/isomorphvf2.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_vf2pp.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_isomorphvf2.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_vf2userfunc.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_match_helpers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_vf2pp_helpers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_temporalisomorphvf2.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_ismags.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_isomorphism.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/tests/test_tree_isomorphism.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/matchhelpers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/vf2pp.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/isomorph.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/isomorphism/temporalisomorphvf2.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/planarity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/bridges.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/chains.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/regular.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/smallworld.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/sparsifiers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/link_analysis/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/link_analysis/tests/test_pagerank.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/link_analysis/tests/test_hits.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/link_analysis/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/link_analysis/hits_alg.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/binary.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/tests/test_all.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/tests/test_unary.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/tests/test_binary.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/tests/test_product.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/all.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/product.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/operators/unary.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/similarity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/clique.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/disjoint_paths.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/connectivity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/edge_kcomponents.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/edge_augmentation.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/kcomponents.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_kcomponents.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_stoer_wagner.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_kcutsets.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_connectivity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_cuts.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_edge_augmentation.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_disjoint_paths.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/tests/test_edge_kcomponents.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/utils.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/stoerwagner.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/kcutsets.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/connectivity/cuts.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/connectivity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/clustering_coefficient.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/steinertree.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/clique.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/maxcut.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/kcomponents.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_kcomponents.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_treewidth.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_ramsey.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_vertex_cover.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_steinertree.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_distance_measures.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_maxcut.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_density.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_traveling_salesman.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_dominating_set.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_clique.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_connectivity.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_approx_clust_coeff.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/tests/test_matching.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/traveling_salesman.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/dominating_set.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/matching.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/density.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/vertex_cover.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/ramsey.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/treewidth.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/approximation/distance_measures.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/dominating.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/moral.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/lowest_common_ancestors.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/structuralholes.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/swap.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/centrality/current_flow_closeness.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/networkx/algorithms/centrality/reaching.py
# ...
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/eventloop/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/eventloop/ioloop.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/eventloop/future.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/eventloop/zmqstream.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/log/handlers.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/log/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/log/__main__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/devices/monitoredqueue.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/devices/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/devices/monitoredqueuedevice.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/devices/proxydevice.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/devices/basedevice.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/devices/proxysteerabledevice.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/zmq/decorators.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/shellchannel.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/socket_pair.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/thread.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/compiler.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/embed.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/_version.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/connect.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/iostream.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/log.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/parentpoller.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/jsonutil.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/kernelspec.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/control.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/eventloops.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/_eventloop_macos.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/ipkernel.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/client.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/constants.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/blocking.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/channels.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/socket.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/inprocess/manager.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/comm/comm.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/comm/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/comm/manager.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/trio_runner.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/debugger.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/zmqshell.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/utils.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/gui/gtk3embed.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/gui/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/gui/gtkembed.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/heartbeat.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/kernelapp.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/displayhook.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/subshell.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/pylab/backend_inline.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/pylab/config.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/pylab/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/__main__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/ipykernel/subshell_manager.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/relativedelta.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/zoneinfo/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/zoneinfo/rebuild.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/_version.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/_common.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/parser/isoparser.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/parser/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/parser/_parser.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/tzwin.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/rrule.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/utils.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/easter.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/tz/_factories.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/tz/tz.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/tz/_common.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/tz/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/dateutil/tz/win.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/nest_asyncio.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/typing_extensions.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/_xdg.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/macos.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/unix.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/version.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/api.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/android.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/windows.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/platformdirs/__main__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/jupyterlab_widgets/_version.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/jupyterlab_widgets/__init__.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/.venv/lib/python3.11/site-packages/jupyter.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/train_all_color_digits copy.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/project_AAIII_teamCode_lastName1_lastName2.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_utilities.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/diffusion_process.py
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/digits_bw_AI/demo_MNIST_diffusion.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/digits_bw_AI/demo_diffusion_models_generative_AI.ipynb
# /Users/ivandominguez/Desktop/practicas3segundocuatri/apaut3/proyecto/proyecto_AAIII_02_diffusion_models/score_model.py

# %%
import os
for f in sorted(os.listdir(PROJECT_DIR / 'color_digits_cond_checkpoints')):
    path = PROJECT_DIR / 'color_digits_cond_checkpoints' / f
    size_mb = os.path.getsize(path) / 1e6
    print(f"{f}  —  {size_mb:.1f} MB")
# Out:
# color_digits_VP-Cosine.pth  —  5.0 MB
# color_digits_VP-Exponential.pth  —  5.0 MB
# color_digits_VP-Linear.pth  —  5.0 MB

# %%
import os
cond_dir = PROJECT_DIR / 'color_digits_cond_checkpoints'
print("existe:", cond_dir.exists())
if cond_dir.exists():
    for f in os.listdir(cond_dir):
        print(f)
# Out:
# existe: True
# color_digits_VP-Linear.pth
# color_digits_VP-Exponential.pth
# color_digits_VP-Cosine.pth

# %%
import hashlib

def md5(path):
    return hashlib.md5(open(path, 'rb').read()).hexdigest()

for name in ['VP-Linear', 'VP-Cosine', 'VP-Exponential']:
    cond = PROJECT_DIR / 'color_digits_cond_checkpoints' / f'color_digits_{name}.pth'
    uncond = PROJECT_DIR / 'color_digits_checkpoints' / f'color_digits_{name}.pth'
    print(f"{name}: {'IGUALES' if md5(cond) == md5(uncond) else 'distintos'}")
# Out:
# VP-Linear: distintos
# VP-Cosine: distintos
# VP-Exponential: distintos

# %%
import inspect

print(inspect.getsource(process.loss_function))
# Out:
#     def loss_function(
#         self,
#         score_model: nn.Module,
#         x_0: torch.Tensor,
#         eps: float = 1e-5,
#     ) -> torch.Tensor:
#         """Weighted denoising score-matching loss.
#
#         Minimises  E_t E_{x_t|x_0} [ ‖σ_t · s_θ(x_t, t) + ε‖² ]
#
#         which is zero when  s_θ(x_t, t) = ∇_x log p_t(x_t).
#         """
#         t = torch.rand(x_0.shape[0], device=x_0.device) * (1.0 - eps) + eps
#         x_t, noise = self.perturb(x_0, t)
#
#         view_shape = [x_0.shape[0]] + [1] * (x_0.dim() - 1)
#         sigma = self.sigma_t(t.view(*view_shape))
#
#         score = score_model(x_t, t)
#         per_sample = torch.sum(
#             (sigma * score + noise) ** 2,
#             dim=list(range(1, x_0.dim())),
#         )
#         return per_sample.mean()

# %% [markdown]
# ### 1.2 Guidance scale ablation
#
# Same digit, same process — sweep **w** from 0 (unconditional) to 7.
# High w → sharper class identity, less diversity.

# %%
DIGIT       = 3
W_SWEEP     = [0.0, 1.0, 2.0, 3.0, 5.0, 7.0]
N_SAMPLES   = 4
PROC_SHOW   = 'VP-Cosine'

process, model = cond_models[PROC_SHOW]
T = T_FOR[PROC_SHOW]

fig, axes = plt.subplots(len(W_SWEEP), N_SAMPLES,
                          figsize=(N_SAMPLES * 1.3, len(W_SWEEP) * 1.5))
for row_i, w in enumerate(W_SWEEP):
    wrapper = CFGWrapper(model, class_label=DIGIT, cfg_scale=w)
    sams = cfg_sample(process, wrapper, N_SAMPLES, T=T).cpu().clamp(0, 1)
    for col_i in range(N_SAMPLES):
        axes[row_i, col_i].imshow(sams[col_i].permute(1, 2, 0).numpy())
        axes[row_i, col_i].axis('off')
    axes[row_i, 0].set_ylabel(f'w={w}', rotation=0, labelpad=35, fontsize=11)

fig.suptitle(f'Guidance ablation — digit {DIGIT}, {PROC_SHOW}', fontsize=12)
plt.tight_layout()
fig.savefig(out_dir / f'cfg_ablation_digit{DIGIT}.pdf', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ### 1.3 Process comparison — same digit, all three processes
#
# Row = process (Linear / Cosine / Exponential schedule), columns = independent samples.

# %%
DIGIT  = 5
W      = 3.0
N_COLS = 6

fig, axes = plt.subplots(3, N_COLS, figsize=(N_COLS * 1.3, 4.5))
for row_i, (pname, (process, model)) in enumerate(cond_models.items()):
    T = T_FOR[pname]
    wrapper = CFGWrapper(model, class_label=DIGIT, cfg_scale=W)
    sams = cfg_sample(process, wrapper, N_COLS, T=T).cpu().clamp(0, 1)
    for col_i in range(N_COLS):
        axes[row_i, col_i].imshow(sams[col_i].permute(1, 2, 0).numpy())
        axes[row_i, col_i].axis('off')
    axes[row_i, 0].set_ylabel(pname, rotation=0, labelpad=80, fontsize=10)

fig.suptitle(f'Process comparison — digit {DIGIT}, w={W}', fontsize=12)
plt.tight_layout()
fig.savefig(out_dir / f'process_comparison_digit{DIGIT}.pdf', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ---
# ## Part 2 — Imputation
#
# We load the **unconditional** VP-Cosine model and use `ImputationSampler` to reconstruct masked-out regions of real SVHN images.
#
# **Mask convention:** `mask = 1` → known pixel (preserved), `mask = 0` → unknown (inferred).

# %%
from score_model_digits_color import ScoreNet as ScoreNetColor

UNCOND_CKPT_DIR = PROJECT_DIR / 'color_digits_checkpoints'

process_imp = VPProcess(schedule=CosineSchedule())
score_model = ScoreNetColor(marginal_prob_std=process_imp.sigma_t).to(device)
ckpt_path   = UNCOND_CKPT_DIR / 'color_digits_VP-Cosine.pth'
score_model.load_state_dict(torch.load(ckpt_path, map_location=device, weights_only=True))
score_model.eval()
print(f'Loaded: {ckpt_path.name}')
# Out:
# Loaded: color_digits_VP-Cosine.pth

# %%
# Load a small batch of real SVHN images
DATA_PATH = PROJECT_DIR / 'digits_true_color_AI' / 'data' / 'train_32x32.mat'
mat = scipy.io.loadmat(str(DATA_PATH))
X_all = np.transpose(mat['X'], (3, 2, 0, 1)).astype(np.float32) / 255.0  # (N, 3, 32, 32)

N_IMGS  = 6
indices = np.random.choice(len(X_all), N_IMGS, replace=False)
x_real  = torch.from_numpy(X_all[indices])   # (N_IMGS, 3, 32, 32)
print(f'Loaded {N_IMGS} images from SVHN  |  shape: {x_real.shape}')
# Out:
# Loaded 6 images from SVHN  |  shape: torch.Size([6, 3, 32, 32])

# %%
def make_mask(shape, kind):
    """Return a binary mask (B,1,H,W). 1=known, 0=infer."""
    B, C, H, W = shape
    m = torch.ones(B, 1, H, W)
    if kind == 'horizontal_band':
        m[:, :, H // 3 : 2 * H // 3, :] = 0.0
    elif kind == 'center_square':
        m[:, :, H // 4 : 3 * H // 4, W // 4 : 3 * W // 4] = 0.0
    elif kind == 'right_half':
        m[:, :, :, W // 2 :] = 0.0
    elif kind == 'random_50pct':
        m = (torch.rand(B, 1, H, W) > 0.5).float()
    return m

MASK_TYPES = ['horizontal_band', 'center_square', 'right_half', 'random_50pct']

# %%
sampler = ImputationSampler(n_resample=1)

results = {}
for kind in MASK_TYPES:
    print(f'Inpainting with mask: {kind} ...', end=' ', flush=True)
    mask = make_mask(x_real.shape, kind)
    x_filled = sampler.inpaint(
        score_model=score_model,
        process=process_imp,
        x_known=x_real,
        mask=mask,
        n_steps=300,
        device=device,
        T=0.999,
    )
    results[kind] = (mask.cpu(), x_filled.cpu())
    print('done')
# Out:
# Inpainting with mask: horizontal_band ... done
# Inpainting with mask: center_square ... done
# Inpainting with mask: right_half ... done
# Inpainting with mask: random_50pct ... done

# %% [markdown]
# ### 2.1 Visualisation: original / masked / reconstructed
#
# Three columns per mask type; rows show each image in the batch.

# %%
IDX = 0    # which image from the batch to display

fig, axes = plt.subplots(len(MASK_TYPES), 3,
                          figsize=(7, len(MASK_TYPES) * 2.6))
for i, kind in enumerate(MASK_TYPES):
    mask, x_filled = results[kind]
    masked = x_real[IDX] * mask[IDX]   # broadcast 1-channel mask → 3 channels

    axes[i, 0].imshow(x_real[IDX].permute(1, 2, 0).clamp(0, 1).numpy())
    axes[i, 1].imshow(masked.permute(1, 2, 0).clamp(0, 1).numpy())
    axes[i, 2].imshow(x_filled[IDX].permute(1, 2, 0).clamp(0, 1).numpy())
    axes[i, 0].set_ylabel(kind, rotation=90, fontsize=9, labelpad=8)
    for j in range(3):
        axes[i, j].set_xticks([]); axes[i, j].set_yticks([])

axes[0, 0].set_title('original')
axes[0, 1].set_title('masked')
axes[0, 2].set_title('reconstruction')
plt.tight_layout()
fig.savefig(out_dir / 'imputation_masks.pdf', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ### 2.2 Diversity — multiple reconstructions for the same mask
#
# Because the sampler is stochastic, running it multiple times on the same masked image yields different plausible completions.
# This illustrates that the inpainting problem is ill-posed.

# %%
N_REC  = 6
KIND   = 'center_square'
IMG_I  = 0

x_one = x_real[IMG_I : IMG_I + 1].to(device)
mask  = make_mask(x_one.shape, KIND).to(device)

recs = []
for i in range(N_REC):
    print(f'  reconstruction {i + 1}/{N_REC}...', end=' ', flush=True)
    x_filled = sampler.inpaint(
        score_model=score_model, process=process_imp,
        x_known=x_one, mask=mask,
        n_steps=300, device=device, T=0.999,
    )
    recs.append(x_filled[0].cpu())
    print('done')

fig, axes = plt.subplots(1, N_REC + 2, figsize=((N_REC + 2) * 1.7, 2.4))
axes[0].imshow(x_one[0].cpu().permute(1, 2, 0).clamp(0, 1).numpy())
axes[0].set_title('original')
masked_show = (x_one[0] * mask[0]).cpu().permute(1, 2, 0).clamp(0, 1).numpy()
axes[1].imshow(masked_show)
axes[1].set_title('masked')
for i, rec in enumerate(recs):
    axes[i + 2].imshow(rec.permute(1, 2, 0).clamp(0, 1).numpy())
    axes[i + 2].set_title(f'#{i + 1}')
for ax in axes:
    ax.axis('off')
fig.suptitle(f'Imputation diversity — mask: {KIND}', y=1.02, fontsize=12)
plt.tight_layout()
fig.savefig(out_dir / 'imputation_diversity.pdf', bbox_inches='tight', dpi=150)
plt.show()
# Out:
#   reconstruction 1/6... done
#   reconstruction 2/6... done
#   reconstruction 3/6... done
#   reconstruction 4/6... done
#   reconstruction 5/6... done
#   reconstruction 6/6... done

# %% [markdown]
# ### 2.3 Sanity check — known pixels must be preserved exactly
#
# `ImputationSampler` pins the known pixels at t≈0, so `mask * x_filled` should equal `mask * x_real` up to floating-point precision.

# %%
for kind in MASK_TYPES:
    mask_cpu, x_filled_cpu = results[kind]
    residual = ((mask_cpu * x_filled_cpu) - (mask_cpu * x_real)).abs().max().item()
    n_known  = int(mask_cpu.sum().item())
    print(f'{kind:<20}  max error in known pixels: {residual:.2e}   known px: {n_known}')
# Out:
# horizontal_band       max error in known pixels: 0.00e+00   known px: 4032
# center_square         max error in known pixels: 0.00e+00   known px: 4608
# right_half            max error in known pixels: 0.00e+00   known px: 3072
# random_50pct          max error in known pixels: 0.00e+00   known px: 3052
